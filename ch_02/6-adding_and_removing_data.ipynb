# %% [markdown]
# # Adding and Removing Data
# We will be working with the `data/earthquakes.csv` file again, so we need to handle our imports and read it in.
#
# ## About the Data
# In this notebook, we will be working with Earthquake data from September 18, 2018 - October 13, 2018 (obtained from the US Geological Survey (USGS) using the [USGS API](https://earthquake.usgs.gov/fdsnws/event/1/))
#
# ## Setup

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data/earthquakes.csv')

# %% [markdown]
# ## Creating new data
# ### Adding new columns
# New columns get added to the right of the dataframe and can be a single value:

# %%
df['ones'] = 1
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType ...      status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml ...   automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml ...   automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml ...   automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml ...   automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md ...   automatic
#
#             time                          title tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA       0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA       0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA       0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA       0  earthquake
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA       0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
#
#                                                  url ones
# 0  https://earthquake.usgs.gov/earthquakes/eventp...    1
# 1  https://earthquake.usgs.gov/earthquakes/eventp...    1
# 2  https://earthquake.usgs.gov/earthquakes/eventp...    1
# 3  https://earthquake.usgs.gov/earthquakes/eventp...    1
# 4  https://earthquake.usgs.gov/earthquakes/eventp...    1
#
# [5 rows x 27 columns]

# %% [markdown]
# ...or a Boolean mask:

# %%
df['mag_negative'] = df.mag < 0
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType     ...       \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml     ...
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml     ...
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml     ...
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml     ...
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md     ...
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA        0  earthquake
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA        0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
#
#                                                  url  ones mag_negative
# 0  https://earthquake.usgs.gov/earthquakes/eventp...     1        False
# 1  https://earthquake.usgs.gov/earthquakes/eventp...     1        False
# 2  https://earthquake.usgs.gov/earthquakes/eventp...     1        False
# 3  https://earthquake.usgs.gov/earthquakes/eventp...     1        False
# 4  https://earthquake.usgs.gov/earthquakes/eventp...     1        False
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Adding the `parsed_place` column
# We have an entity recognition problem on our hands with the `place` column. There are several entities that have multiple names in the data (e.g., CA and California, NV and Nevada).

# %%
df.place.str.extract(r', (.*$)')[0].sort_values().unique()
# Out:
# array(['Afghanistan', 'Alaska', 'Argentina', 'Arizona', 'Arkansas',
#        'Australia', 'Azerbaijan', 'B.C., MX', 'Barbuda', 'Bolivia',
#        'Bonaire, Saint Eustatius and Saba ', 'British Virgin Islands',
#        'Burma', 'CA', 'California', 'Canada', 'Chile', 'China',
#        'Christmas Island', 'Colombia', 'Colorado', 'Costa Rica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'Ecuador region',
#        'El Salvador', 'Fiji', 'Greece', 'Greenland', 'Guam', 'Guatemala',
#        'Haiti', 'Hawaii', 'Honduras', 'Idaho', 'Illinois', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Italy', 'Jamaica', 'Japan', 'Kansas',
#        'Kentucky', 'Kyrgyzstan', 'Martinique', 'Mauritius', 'Mayotte',
#        'Mexico', 'Missouri', 'Montana', 'NV', 'Nevada', 'New Caledonia',
#        'New Hampshire', 'New Mexico', 'New Zealand', 'Nicaragua',
#        'North Carolina', 'Northern Mariana Islands', 'Oklahoma', 'Oregon',
#        'Pakistan', 'Papua New Guinea', 'Peru', 'Philippines',
#        'Puerto Rico', 'Romania', 'Russia', 'Saint Helena',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Carolina',
#        'South Georgia and the South Sandwich Islands',
#        'South Sandwich Islands', 'Taiwan', 'Tajikistan', 'Tennessee',
#        'Texas', 'Tonga', 'Turkey', 'U.S. Virgin Islands', 'Utah',
#        'Uzbekistan', 'Vanuatu', 'Vermont', 'Washington', 'Wyoming',
#        'Yemen', nan], dtype=object)

# %% [markdown]
# Replace parts of the `place` names to fit our needs:

# %%
df['parsed_place'] = df.place.str.replace(
    r'.* of ', '' # remove anything saying <something> of <something>
).str.replace(
    r'the ', '' # remove things starting with "the"
).str.replace(
    r'CA$', 'California' # fix California
).str.replace(
    r'NV$', 'Nevada' # fix Nevada
).str.replace(
    r'MX$', 'Mexico' # fix Mexico
).str.replace(
    r' region$', '' # chop off endings with "region"
).str.replace(
    r'northern ', '' # remove "northern"
).str.replace(
    r'Fiji Islands', 'Fiji' # line up the Fiji places
).str.replace(
    r'^.*, ', '' # remove anything else extraneous from the beginning
).str.strip() # remove any extra spaces

# %% [markdown]
# Now we can use a single name to get all earthquakes for that place:

# %%
df.parsed_place.sort_values().unique()
# Out:
# array(['Afghanistan', 'Alaska', 'Argentina', 'Arizona', 'Arkansas',
#        'Ascension Island', 'Australia', 'Azerbaijan', 'Balleny Islands',
#        'Barbuda', 'Bolivia', 'British Virgin Islands', 'Burma',
#        'California', 'Canada', 'Carlsberg Ridge',
#        'Central East Pacific Rise', 'Central Mid-Atlantic Ridge', 'Chile',
#        'China', 'Christmas Island', 'Colombia', 'Colorado', 'Costa Rica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'El Salvador',
#        'Fiji', 'Greece', 'Greenland', 'Guam', 'Guatemala', 'Haiti',
#        'Hawaii', 'Honduras', 'Idaho', 'Illinois', 'India',
#        'Indian Ocean Triple Junction', 'Indonesia', 'Iran', 'Iraq',
#        'Italy', 'Jamaica', 'Japan', 'Kansas', 'Kentucky',
#        'Kermadec Islands', 'Kuril Islands', 'Kyrgyzstan', 'Martinique',
#        'Mauritius', 'Mayotte', 'Mexico', 'Mid-Indian Ridge', 'Missouri',
#        'Montana', 'Nevada', 'New Caledonia', 'New Hampshire',
#        'New Mexico', 'New Zealand', 'Nicaragua', 'North Carolina',
#        'Northern East Pacific Rise', 'Northern Mariana Islands',
#        'Northern Mid-Atlantic Ridge', 'Oklahoma', 'Oregon',
#        'Pacific-Antarctic Ridge', 'Pakistan', 'Papua New Guinea', 'Peru',
#        'Philippines', 'Prince Edward Islands', 'Puerto Rico',
#        'Queen Charlotte Islands', 'Romania', 'Russia',
#        'Saint Eustatius and Saba', 'Saint Helena', 'Socotra',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Carolina',
#        'South Georgia and South Sandwich Islands',
#        'South Sandwich Islands', 'Southeast Indian Ridge',
#        'Southern East Pacific Rise', 'Southern Mid-Atlantic Ridge',
#        'Southwest Indian Ridge', 'Sumatra', 'Taiwan', 'Tajikistan',
#        'Tennessee', 'Texas', 'Tonga', 'Turkey', 'U.S. Virgin Islands',
#        'Utah', 'Uzbekistan', 'Vanuatu', 'Vermont', 'Washington',
#        'Western Indian-Antarctic Ridge', 'Western Xizang', 'Wyoming',
#        'Yemen'], dtype=object)

# %% [markdown]
# #### Using the `assign()` method to create columns
# To create many columns at once or update existing columns, we can use `assign()`:

# %%
df.assign(
    in_ca=df.parsed_place.str.endswith('California'),
    in_alaska=df.parsed_place.str.endswith('Alaska')
).head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType    ...           type  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml    ...     earthquake
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml    ...     earthquake
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml    ...     earthquake
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml    ...     earthquake
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md    ...     earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
#
#                                                  url  ones mag_negative  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...     1        False
# 1  https://earthquake.usgs.gov/earthquakes/eventp...     1        False
# 2  https://earthquake.usgs.gov/earthquakes/eventp...     1        False
# 3  https://earthquake.usgs.gov/earthquakes/eventp...     1        False
# 4  https://earthquake.usgs.gov/earthquakes/eventp...     1        False
#
#   parsed_place  in_ca in_alaska
# 0   California   True     False
# 1   California   True     False
# 2   California   True     False
# 3   California   True     False
# 4   California   True     False
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Concatenation
# We can concatenate along the column axis (`axis=1`) with `pd.concat()` to add columns to our dataframe (these get added to the right of the dataframe in the following example):

# %%
pd.concat(
    [df.head(), pd.Series(np.arange(5), name='arange')],
    axis=1
)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...    tsunami  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...          0
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...          0
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...          0
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...          0
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...          0
#
#          type                                              types     tz  \
# 0  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 1  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 2  earthquake  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0
# 3  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 4  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0
#
#          updated                                                url ones  \
# 0  1539475395144  https://earthquake.usgs.gov/earthquakes/eventp...    1
# 1  1539475253925  https://earthquake.usgs.gov/earthquakes/eventp...    1
# 2  1539536756176  https://earthquake.usgs.gov/earthquakes/eventp...    1
# 3  1539475196167  https://earthquake.usgs.gov/earthquakes/eventp...    1
# 4  1539477547926  https://earthquake.usgs.gov/earthquakes/eventp...    1
#
#   mag_negative  parsed_place arange
# 0        False    California      0
# 1        False    California      1
# 2        False    California      2
# 3        False    California      3
# 4        False    California      4
#
# [5 rows x 30 columns]

# %% [markdown]
# Concatenating along the row axis (`axis=0`) is equivalent to appending to the bottom (look at the last 2 rows here):

# %%
pd.concat([
    df.head(), df[0:2]],
    axis=0
)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType     ...       \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml     ...
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml     ...
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml     ...
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml     ...
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md     ...
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml     ...
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml     ...
#
#                            title tsunami        type  \
# 0  M 1.4 - 9km NE of Aguanga, CA       0  earthquake
# 1  M 1.3 - 9km NE of Aguanga, CA       0  earthquake
# 2  M 3.4 - 8km NE of Aguanga, CA       0  earthquake
# 3  M 0.4 - 9km NE of Aguanga, CA       0  earthquake
# 4  M 2.2 - 10km NW of Avenal, CA       0  earthquake
# 0  M 1.4 - 9km NE of Aguanga, CA       0  earthquake
# 1  M 1.3 - 9km NE of Aguanga, CA       0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url ones  mag_negative  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 1  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 2  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 3  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 4  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 0  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 1  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
#
#   parsed_place
# 0   California
# 1   California
# 2   California
# 3   California
# 4   California
# 0   California
# 1   California
#
# [7 rows x 29 columns]

# %% [markdown]
# Note that the previous result is equivalent to running the `append()` method of the dataframe:

# %%
df.head().append(df[0:2])
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType     ...       \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml     ...
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml     ...
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml     ...
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml     ...
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md     ...
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml     ...
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml     ...
#
#                            title tsunami        type  \
# 0  M 1.4 - 9km NE of Aguanga, CA       0  earthquake
# 1  M 1.3 - 9km NE of Aguanga, CA       0  earthquake
# 2  M 3.4 - 8km NE of Aguanga, CA       0  earthquake
# 3  M 0.4 - 9km NE of Aguanga, CA       0  earthquake
# 4  M 2.2 - 10km NW of Avenal, CA       0  earthquake
# 0  M 1.4 - 9km NE of Aguanga, CA       0  earthquake
# 1  M 1.3 - 9km NE of Aguanga, CA       0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url ones  mag_negative  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 1  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 2  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 3  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 4  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 0  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
# 1  https://earthquake.usgs.gov/earthquakes/eventp...    1         False
#
#   parsed_place
# 0   California
# 1   California
# 2   California
# 3   California
# 4   California
# 0   California
# 1   California
#
# [7 rows x 29 columns]

# %% [markdown]
# ## Deleting Unwanted Data
# Columns can be deleted using dictionary syntax with `del`:

# %%
del df['url']
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'ones', 'mag_negative', 'parsed_place'],
#       dtype='object')

# %% [markdown]
# We can also use `pop()`. This will allow us to use the series we remove later:

# %%
mag_negative = df.pop('mag_negative')
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'ones', 'parsed_place'],
#       dtype='object')

# %% [markdown]
# Notice we have a mask in `mag_negative` now:

# %%
mag_negative.value_counts()
# Out:
# False    8841
# True      491
# Name: mag_negative, dtype: int64

# %% [markdown]
# Now we can use `mag_negative` to select:

# %%
df[mag_negative].head()
# Out:
#     alert  cdi      code                                             detail  \
# 39    NaN  NaN  00660886  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 49    NaN  NaN  00660884  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 135   NaN  NaN  00660897  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 161   NaN  NaN  80314084  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 198   NaN  NaN  00660745  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#       dmin  felt     gap           ids   mag magType     ...         status  \
# 39   0.095   NaN  155.25  ,nn00660886, -0.10      ml     ...       reviewed
# 49   0.097   NaN  155.98  ,nn00660884, -0.10      ml     ...       reviewed
# 135  0.092   NaN   71.82  ,nn00660897, -0.40      ml     ...       reviewed
# 161  0.148   NaN  117.00  ,mb80314084, -0.02      md     ...       reviewed
# 198  0.047   NaN   65.16  ,nn00660745, -0.20      ml     ...       reviewed
#
#               time                                     title tsunami  \
# 39   1539458844506  M -0.1 - 6km NW of Lemmon Valley, Nevada       0
# 49   1539455017464  M -0.1 - 6km NW of Lemmon Valley, Nevada       0
# 135  1539422175717       M -0.4 - 10km SSE of Beatty, Nevada       0
# 161  1539412475360       M -0.0 - 20km SSE of Ronan, Montana       0
# 198  1539398340822        M -0.2 - 60km N of Pahrump, Nevada       0
#
#            type                         types     tz        updated  ones  \
# 39   earthquake  ,geoserve,origin,phase-data, -480.0  1539482703428     1
# 49   earthquake  ,geoserve,origin,phase-data, -480.0  1539482700579     1
# 135  earthquake  ,geoserve,origin,phase-data, -480.0  1539482715521     1
# 161  earthquake  ,geoserve,origin,phase-data, -420.0  1539433905970     1
# 198  earthquake  ,geoserve,origin,phase-data, -480.0  1539482652322     1
#
#     parsed_place
# 39        Nevada
# 49        Nevada
# 135       Nevada
# 161      Montana
# 198       Nevada
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Using the `drop()` method
# We can drop rows by passing a list of indices to the `drop()` method. Notice in the following example that when asking for the first 2 rows with `head()` we get the 3rd and 4th rows because we dropped the original first 2 with `drop([0, 1])`:

# %%
df.drop([0, 1]).head(2)
# Out:
#   alert  cdi      code                                             detail  \
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#       dmin  felt   gap           ids   mag magType     ...          status  \
# 2  0.02137  28.0  21.0  ,ci37389194,  3.42      ml     ...       automatic
# 3  0.02618   NaN  39.0  ,ci37389186,  0.44      ml     ...       automatic
#
#             time                          title tsunami        type  \
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA       0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA       0  earthquake
#
#                                                types     tz        updated  \
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
#
#    ones parsed_place
# 2     1   California
# 3     1   California
#
# [2 rows x 27 columns]

# %% [markdown]
# The `drop()` method drops along the row axis by default. If we pass in `axis=1` for the column axis, we can delete columns:

# %%
df.drop(
    columns=[col for col in df.columns \
             if col not in \
             ['alert', 'mag', 'title', 'time', 'tsunami']]
).head()
# Out:
#   alert   mag           time                          title  tsunami
# 0   NaN  1.35  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0
# 1   NaN  1.29  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0
# 2   NaN  3.42  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0
# 3   NaN  0.44  1539474978070  M 0.4 - 9km NE of Aguanga, CA        0
# 4   NaN  2.16  1539474716050  M 2.2 - 10km NW of Avenal, CA        0

# %% [markdown]
# We also have the option of passing the column names to the `columns` parameter instead of using `axis=1`:

# %%
df.drop(
    columns=[col for col in df.columns \
             if col not in \
             ['alert', 'mag', 'title', 'time', 'tsunami']]
).equals(
    df.drop(
        [col for col in df.columns \
         if col not in ['alert', 'mag', 'title', 'time', 'tsunami']],
        axis=1
    )
)
# Out:
# True

# %% [markdown]
# By default, `drop()`, along with the majority of `DataFrame` methods, will return a new `DataFrame` object. If we just want to change the one we are working with, we can pass `inplace=True`. This should be used with care:

# %%
df.drop(
    columns=[col for col in df.columns \
             if col not in \
             ['alert', 'mag', 'parsed_place', 'time', 'tsunami']],
    inplace=True
)
df.head()
# Out:
#   alert   mag           time  tsunami parsed_place
# 0   NaN  1.35  1539475168010        0   California
# 1   NaN  1.29  1539475129610        0   California
# 2   NaN  3.42  1539475062610        0   California
# 3   NaN  0.44  1539474978070        0   California
# 4   NaN  2.16  1539474716050        0   California
